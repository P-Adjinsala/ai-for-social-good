# %% [markdown]
# # Module 04 — Project Starter Notebook
# ## Civic Tech Project Template
#
# **Course:** AI for Social Good | **Module:** 04 — Civic Tech Project
#
# This notebook is your starting template. Replace each section with your own
# project work. The structure and comments guide you through each step.
#
# ---

# %% [markdown]
# ## Project Title
# *Replace this with your project title*
#
# **Student name:**
# **Region/context:**
# **Civic problem addressed:**
# **Dataset used:**
# **Date:**

# %% [markdown]
# ## 1. Problem Statement
#
# Write 150–200 words here describing:
# - The specific civic problem you are addressing
# - Who is affected and how
# - Why data analysis can help
#
# *Your text here*

# %% [markdown]
# ## 2. Setup & Data Loading

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.dpi'] = 110
sns.set_theme(style='whitegrid')

# Load your dataset here
# Option A — CSV from GitHub or Google Drive:
# df = pd.read_csv('YOUR_DATA_URL_HERE')

# Option B — World Bank API (see module 02 notebook for full example):
# !pip install wbgapi -q
# import wbgapi as wb
# df = wb.data.DataFrame(['YOUR_INDICATOR'], economy='CMR', time=range(2000,2023))

# Option C — Use the course sample dataset:
df = pd.read_csv('../datasets/civic_survey_sample.csv')
print(f'Dataset loaded: {df.shape[0]} rows x {df.shape[1]} columns')
df.head()

# %% [markdown]
# ## 3. Data Cleaning
#
# Document your cleaning steps here. For each issue found, explain:
# - What the problem was
# - How you handled it
# - Why you made that choice

# %%
# Step 1 — Check for missing values
print('Missing values:')
print(df.isnull().sum())

# Step 2 — Check data types
print('\nData types:')
print(df.dtypes)

# Add your cleaning steps below
# ...

df_clean = df.copy()  # replace with your cleaned version
print(f'\nClean dataset: {df_clean.shape}')

# %% [markdown]
# ## 4. Exploratory Analysis
#
# Create at least 3 visualisations that tell a story about your data.
# Each chart should have a title and axis labels.

# %%
# Chart 1 — Overview
# Replace with your own chart
fig, ax = plt.subplots(figsize=(10, 5))
df_clean['region'].value_counts().plot(kind='barh', ax=ax, color='steelblue')
ax.set_title('Distribution by Region', fontweight='bold')
ax.set_xlabel('Count')
plt.tight_layout()
plt.show()

# %%
# Chart 2 — Key finding
# Your code here

# %%
# Chart 3 — Disaggregation or comparison
# Your code here

# %% [markdown]
# ## 5. Key Findings
#
# Summarise your 3 most important findings here in plain language (one sentence each):
#
# 1. *Finding 1*
# 2. *Finding 2*
# 3. *Finding 3*

# %% [markdown]
# ## 6. Ethical Reflection
#
# Address these questions (100-150 words total):
#
# - What are the limitations of your data or analysis?
# - Who might be harmed if this analysis is misused or misinterpreted?
# - What would need to be true for this analysis to justify a real policy recommendation?
#
# *Your reflection here*

# %% [markdown]
# ## 7. Conclusion & Next Steps
#
# What would you do next if you had more time and resources?
# How could this analysis be made more useful for the community it concerns?
#
# *Your conclusion here*
